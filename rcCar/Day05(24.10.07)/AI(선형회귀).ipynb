# %%
# 선형회귀 
from pop import AI

LR = AI.Linear_Regression() # 선형회귀 객체 생성

# %%
# 입력데이터(키)
LR.X_data = [[173], [172], [162], [181], [157], [169], [177], [159], [182]]
# 정답데이터(발크기)
LR.Y_data = [[270], [275], [245], [280], [230], [265], [270], [250], [275]]

# %%
import matplotlib.pyplot as plt
plt.plot(LR.X_data, LR.Y_data)
plt.show()

# %%
plt.plot(LR.X_data, LR.Y_data, 'ro')
plt.show()

# %%
LR.train()
# Out:
# 10 step loss: 35510.88671875
# 20 step loss: 29445.798828125
# 30 step loss: 24102.38671875
# 40 step loss: 19484.978515625
# 50 step loss: 15561.58984375
# 60 step loss: 12277.66796875
# 70 step loss: 9567.546875
# 80 step loss: 7361.8203125
# 90 step loss: 5591.7060546875
# 100 step loss: 4191.58251953125
# Training is done.
# Time spent: 5.2 s
# Training speed: 19.3 step/s

# %%
# 데이터 검증(훈련데이터로 예측값 출력)
pred = LR.run()
# Out:
# run with :  [[173]
#  [172]
#  [162]
#  [181]
#  [157]
#  [169]
#  [177]
#  [159]
#  [182]]

# %%
plt.plot(LR.X_data, pred, 'ro')
plt.show()

# %%
LR.train(times=1000, print_every=100)
# Out:
# 200 step loss: 138.1437530517578
# 300 step loss: 40.44258499145508
# 400 step loss: 40.02219009399414
# 500 step loss: 40.02182388305664
# 600 step loss: 40.02165603637695
# 700 step loss: 40.021522521972656
# 800 step loss: 40.02130889892578
# 900 step loss: 40.02117156982422
# 1000 step loss: 40.020938873291016
# 1100 step loss: 40.02065658569336
# Training is done.
# Time spent: 5.0 s
# Training speed: 198.1 step/s

# %%
pred = LR.run()
# Out:
# run with :  [[173]
#  [172]
#  [162]
#  [181]
#  [157]
#  [169]
#  [177]
#  [159]
#  [182]]

# %%
X_pred = ([150], [160], [170], [180], [190])
pred = LR.run(X_pred)

# %%
plt.plot(X_pred, pred, 'ro')
plt.show()

# %%
from pop import AI
LR = AI.Linear_Regression(restore=True)

# %%
LR.X_data = [[173], [172], [162], [181], [157], [169], [177], [159], [182]]
LR.Y_data = [[270], [275], [245], [280], [230], [265], [270], [250], [275]]

# %%
LR.run()
# Out:
# run with :  [[173]
#  [172]
#  [162]
#  [181]
#  [157]
#  [169]
#  [177]
#  [159]
#  [182]]
# array([[266.54498],
#        [265.01108],
#        [249.67183],
#        [278.81638],
#        [242.0022 ],
#        [260.4093 ],
#        [272.6807 ],
#        [245.07005],
#        [280.3503 ]], dtype=float32)

# %%
LR.train()
# Out:
# 1110 step loss: 40.02060317993164
# 1120 step loss: 40.02070617675781
# 1130 step loss: 40.02067947387695
# 1140 step loss: 40.020591735839844
# 1150 step loss: 40.02061080932617
# 1160 step loss: 40.02062225341797
# 1170 step loss: 40.020484924316406
# 1180 step loss: 40.02043914794922
# 1190 step loss: 40.02050018310547
# 1200 step loss: 40.02048110961914
# Training is done.
# Time spent: 1.0 s
# Training speed: 97.6 step/s

# %%
LR = AI.Linear_Regression(restore=True, ckpt_name="model_01") # 안됨 왜안됨
# Out:
# [Error] Can't find a model in 'model_01'.
# Create a new model.

# %%
from pop import AI
LR = AI.Logistic_Regression()

LR.X_data = [[173], [171], [162], [187], [157], [169], [177], [159], [182]]
LR.Y_data = [[0], [1], [1], [0], [1], [0], [0], [1], [0]]

LR.train()
LR.run()
# Out:
# 10 step loss: 0.787859320640564
# 20 step loss: 0.6893322467803955
# 30 step loss: 0.8309881091117859
# 40 step loss: 1.1627655029296875
# 50 step loss: 0.7052555084228516
# 60 step loss: 1.0698130130767822
# 70 step loss: 0.9162480235099792
# 80 step loss: 0.993367612361908
# 90 step loss: 0.7951136827468872
# 100 step loss: 0.8814249038696289
# Training is done.
# Time spent: 1.8 s
# Training speed: 55.1 step/s
# run with :  [[173]
#  [171]
#  [162]
#  [187]
#  [157]
#  [169]
#  [177]
#  [159]
#  [182]]
# array([[0.8219191 ],
#        [0.8225603 ],
#        [0.82542306],
#        [0.8173802 ],
#        [0.82699776],
#        [0.82319957],
#        [0.8206314 ],
#        [0.8263692 ],
#        [0.8190115 ]], dtype=float32)

# %%
import matplotlib.pyplot as plt
plt.plot(X_data, pred, 'ro')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-b12b721cfdca> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(X_data, pred, 'ro')
#       3 plt.show()
#
# NameError: name 'X_data' is not defined

# %%
X_pred = [[150], [160], [170], [180], [190]]
pred = LR.run(X_pred)

# %%
plt.plot(X_pred, pred, 'ro')
plt.show()
